# %%
import numpy as np
import os
import cPickle as pkl
import scipy.signal
import numpy.fft as fft
import sys
import optparse
from PIL import Image
import re
import itertools
from scipy import ndimage

import time
import datetime

import pandas as pd

from bokeh.io import gridplot, output_file, show
from bokeh.plotting import figure
import csv

import pymworks 
import pandas as pd
import operator
import codecs

import scipy.io
import copy


# Abstract struct class       
class Struct:
    def __init__ (self, *argv, **argd):
        if len(argd):
            # Update by dictionary
            self.__dict__.update (argd)
        else:
            # Update by position
            attrs = filter (lambda x: x[0:2] != "__", dir(self))
            for n in range(len(argv)):
                setattr(self, attrs[n], argv[n])


class cycstruct(Struct):
    times = []
    idxs = 0
    vals = 0
    ordernum = 0
    triggers = 0

def get_timekey(item):
    return item.time

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="21fa6223-b3f1-42d7-a64a-7fc478b168a8">Loading BokehJS ...</span>
#     </div>

# %%
def get_session_bounds(dfn):
    df = None
    df = pymworks.open(dfn)                                                          # Open the datafile

    # First, find experiment start, stop, or pause events:
    modes = df.get_events('#state_system_mode')                                      # Find timestamps for run-time start and end (2=run)
    start_ev = [i for i in modes if i['value']==2][0]                                # 2=running, 0 or 1 = stopped

    run_idxs = [i for i,e in enumerate(modes) if e['time']>start_ev['time']]         # Get all "run states" if more than 1 found

    end_ev = next(i for i in modes[run_idxs[0]:] if i['value']==0 or i['value']==1)  # Find the first "stop" event after the first "run" event

    # Create a list of runs using start/stop-event times (so long as "Stop" button was not pressed during acquisition, only 1 chunk of time)
    bounds = []
    bounds.append([start_ev.time, end_ev.time])
    for r in run_idxs[1:]: 
        if modes[r].time < end_ev.time:  # Ignore any extra "run" events if there was no actual "stop" event
            continue
        else:                            # Otherwise, find the next "stop" event if any additional/new "run" events found.
            try:
                stop_ev = next(i for i in modes[r:] if i['value']==0 or i['value']==1)
            except StopIteration:
                end_event_name = 'trial_end'
                print "NO STOP DETECTED IN STATE MODES. Using alternative timestamp: %s." % end_event_name
                stop_ev = df.get_events(end_event_name)[-1]
                print stop_ev
            bounds.append([modes[r]['time'], stop_ev['time']])

    bounds[:] = [x for x in bounds if ((x[1]-x[0])/1E6)>1]
    # print "................................................................"
    print "****************************************************************"
    print "Parsing file\n%s... " % dfn
    print "Found %i start events in session." % len(bounds)
    print "Bounds: ", bounds
    for bidx, bound in enumerate(bounds):
        print "bound ID:", bidx, (bound[1]-bound[0])/1E6, "sec"
    print "****************************************************************"

    return df, bounds

# %%
def get_image_events(df, boundary, pixelclock_evs=[], stimtype='grating', mask=False):
    
    # Get all stimulus-udpate events within bounds:
    tmp_display_evs = df.get_events('#stimDisplayUpdate')                                                  # Get all stimulus-display-update events
    display_evs = [e for e in tmp_display_evs if e.value and not e.value[0]==None]                         # Filter out empty display-update events
    display_evs = [d for d in display_evs if d.time <= boundary[1] and d.time >= boundary[0]]              # Only include display-update events within time boundary of the session

    if len(pixelclock_evs)>0:
        pixelclock_evs = [i for i in display_evs for v in i.value if 'bit_code' in v.keys()]
        num_non_stimuli = 3 # N stimuli on screen: pixel clock, background, image
    if len(pixelclock_evs)==0:
        print "No pixel clock."
        pixelclock_evs = display_evs
        num_non_stimuli = 2 # N stimuli on screen: background, image
       
    # Get stimulus-onset info parsed into trials:
    if stimtype=='image':
        tmp_image_evs = [d for d in pixelclock_evs for i in d.value if 'filename' in i.keys() and '.png' in i['filename']]
        #stimevents.append(imdevs)

        # Find blank ITIs:
        if mask is True:
            iti_evs = [i for i in pixelclock_evs for v in i.value if v['name']=='blue_mask' and i not in tmp_image_evs]
        else:
            iti_evs = [i for i in pixelclock_evs if i.time>image_evs[0].time and i not in tmp_image_evs]

        tmp_trial_evs = tmp_image_evs + iti_evs
        trial_evs = sorted(tmp_trial_evs, key=get_timekey)
        
        image_evs = tmp_image_evs

    elif stimtype=='grating':
        #tmp_image_evs = [d for d in display_evs for i in d.value if i['name']=='gabor']
        tmp_image_evs = [d for d in display_evs for i in d.value if i['type']=='drifting_grating']
        
        start_times = [i.value[1]['start_time'] for i in tmp_image_evs] # Use start_time to ignore dynamic pixel-code of drifting grating since stim as actually static
        find_static = np.where(np.diff(start_times) > 0)[0]
        find_static = np.append(find_static, 0)
        find_static = sorted(find_static)
        image_evs = [tmp_image_evs[i+1] for i in find_static]
        print "got image events"
        #stimevents.append(imtrials)
        
        # Make sure only the 1st stimulus after a new-stim flag is counted (for guarantee-reward) experiments:
        newstim_evs = df.get_events('new_stimulus')
        new_stim_evs = [i for i in newstim_evs if i.value==1]
        print "N new-stimulus events:", len(new_stim_evs)
        first_image_idxs = []
        for idx,newev in enumerate(new_stim_evs[0:-1]):
            possible_image_evs = [i for i,ev in enumerate(image_evs) if ev.time>newev.time and ev.time<new_stim_evs[idx+1].time]
            first_image_idxs.append(possible_image_evs)
        first_image_idxs = [i[0] for i in first_image_idxs if len(i)>0]
        image_evs = [image_evs[i] for i,ev in enumerate(image_evs) if i in first_image_idxs]
        print "N image evs after taking only first image: ", len(image_evs)
        
        # Filter out image-events that were aborted:
        aborted_evs = df.get_events('trial_aborted')
        aborted_idxs = []
        aborted_evs = []
        for idx,imev in enumerate(image_evs[0:-1]):
            check_abort = [i.value for i in aborted_evs if i.time>imev.time and i.time<image_evs[idx+1].time]
            if sum(check_abort)>0:
                aborted_idxs.append(idx)
                aborted_evs.append(imev)
        print "N aborted images: ", len(aborted_idxs)
        image_evs = [image_evs[i] for i,ev in enumerate(image_evs) if i not in aborted_idxs]
        print "N image evs after removing aborted: ", len(image_evs)
        
        # Find blank ITIs:
        if mask is True:
            iti_evs = [i for i in pixelclock_evs if i.time>tmp_image_evs[0].time and i not in tmp_image_evs]
        else:
#             prevdev = [[i for i,d in enumerate(display_evs) if d.time < t.time][-1] for t in image_evs[1:]]
#             lastdev = [i for i,d in enumerate(display_evs) if d.time > image_evs[-1].time and len(d.value)<num_non_stimuli] # ignore the last "extra" ev (has diff time-stamp) - just wnt 1st non-grating blank
#             iti_evs = [display_evs[i] for i in prevdev]
#             if len(lastdev)>0:
#                 iti_evs.append(display_evs[lastdev[0]])
            #nonstim_evs = [i for i in display_evs if i not in tmp_image_evs]
            
            im_idx = [[t.time for t in display_evs].index(i.time) for i in image_evs]
            iti_evs = []
            for im in im_idx:
                try:
                    next_iti = next(i for i in display_evs[im:] if len(i.value)==(num_non_stimuli-1))
                    iti_evs.append(next_iti)
                except StopIteration:
                    print "No ITI found after this (should be last image_ev).\n"
                    #print display_evs[im]
            print "got iti events"
        
        # Check that we got all the blanks:
#         blanks = [i for i,p in enumerate(pixelclock_evs) if len(p.value)==(num_non_stimuli-1)]
#         mismatches = [i for i,(p,t) in enumerate(zip([pixelclock_evs[x] for x in blanks], iti_evs)) if not p==t]   
#         if len(mismatches)>0:
#             print "Mismatches found in parsing trials...."
#             print mismatches

        # Append a "trial off" at end, if needed:
        if image_evs[-1].time > iti_evs[-1].time: # early-abort
            print "Removing extra image event that has no offset."
            image_evs.pop(-1)                
        tmp_trial_evs = image_evs + iti_evs
        trial_evs = sorted(tmp_trial_evs, key=get_timekey)

    #trialevents.append(tmp_trialevents)
    print "Length of trial epochs: ", len(trial_evs)
    print "Number of trials found: ", len(image_evs)
    
    return image_evs, trial_evs, aborted_evs

# %%
def get_session_info(df):
    info = dict()
    
    stimon = df.get_events('stim_on_time')
    info['stimulus_duration'] = stimon[-1].value
    itis = df.get_events('ITI_duration')
    info['iti_duration'] = itis[-1].value
    sizes = df.get_events('fullscreen_size')
    info['stimsize'] = sizes[-1].value
    # stimulus types?
    # ntrials?
    portside = df.get_events('A_port')
    info['A_port'] = portside[-1].value
    
    return info

# %%
# From pymworks:
class Stimulus(object):
    def __init__(self, time, attributes, pixelclock=None):
        self.time = time
        self.attributes = attributes
        if pixelclock is not None:
            self.attributes['bit_code'] = pixelclock['bit_code']
        self.duration = None

    def __cmp__(self, other):
        return dict.__cmp__(self.attributes, other.attributes)

    def to_dict(self):
        d = self.attributes.copy()
        d.update(dict(time=self.time, duration=self.duration))
        return d

# %%
blacklisttests = [
    #lambda s: (('name' in s.keys()) and (s['name'] == 'pixel clock')),
    lambda s: (('type' in s.keys()) and (s['type'] == 'blankscreen')),
    ]

def to_stims(events, as_dicts=True, blacklist=None):
    if blacklist is None:
        blacklist = blacklisttests
    if not isinstance(blacklist, (tuple, list)):
        blacklist = (blacklist, )
    stims = []
    onscreen = []
    for e in sorted(events, key=lambda e: e.time):
        if e.value is None:
            logging.warning("Encountered event with value == None")
            if onscreen != {}:
                logging.error("Event.value == None with items on screen")
            continue
        current = []
        if hasattr(e.value, '__getitem__'):
            stimulus = None
            pixelclock = None
            for stim in e.value:
                if not isinstance(stim, dict) or \
                        any([t(stim) for t in blacklist]):
                    continue
                if ('name' in stim.keys()) and (stim['name'] == 'pixel clock'):
                    pixelclock = stim
                else:
                    if stimulus is not None:
                        logging.warning(
                            "Two stimuli onscreen: %s, %s"
                            % (stimulus, stim))
                    stimulus = stim
            if stimulus is not None:
                current.append(Stimulus(e.time, stimulus, pixelclock))
        #newstims, onscreen = find_stims(onscreen, current, e.time)
        stims += current #newstims
    if as_dicts:
        return [s.to_dict() for s in stims]
    return stims

# %%
def to_trials(stim_display_events, outcome_events, remove_unknown=True,
              duration_multiplier=2, stim_blacklists=None):
    """
    If remove_unknown, any trials where a corresponding outcome_event cannot
    be found will be removed.

    If duration_multiplier is not None, to_trials will check to see if the
    outcome event occured within duration_multiplier * duration microseconds
    of the trial start. If the outcome event occured later, the trial outcome
    will be marked as unknown.
    """
    if (len(outcome_events) == 0) or (len(stim_display_events) == 0):
        return []
    assert hasattr(outcome_events[0], 'name')

    trials = to_stims(stim_display_events, as_dicts=True,
                      blacklist=stim_blacklists)

    if (len(trials) == 0):
        return []

    outcomes = pymworks.events.utils.sync(outcome_events, trials,
                          direction=1, mkey=lambda x: x['time'])

    assert len(trials) == len(outcomes)
    unknowns = []
    if duration_multiplier is None:
        dtest = lambda t, o: True
    else:
        dtest = lambda t, o: \
            o.time < (t['time'] + t['duration'] * duration_multiplier)
    for i in xrange(len(trials)):
        if (outcomes[i] is not None) and dtest(trials[i], outcomes[i]):
            trials[i]['outcome'] = outcomes[i].name
            trials[i]['response_time'] = outcomes[i].time
        else:
            if remove_unknown:
                unknowns.append(i)
            else:
                trials[i]['outcome'] = 'unknown'

    # remove trials with 'unknown' outcome, in reverse
    for u in unknowns[::-1]:
        del trials[u]

    return trials

# %%
def get_first_response(found_outcome_evs):
    true_outcome_events = [f[0] for f in found_outcome_evs]
    first_outcome_evs = sorted([i for i in true_outcome_events], key=lambda e: e.time)

    success_evs = df.get_events('n_successes_session')
    fail_evs = df.get_events('n_failures_session')
    ignore_evs = df.get_events('n_ignores_session')

    result_events = []
    for idx,oev in enumerate(first_outcome_evs):
        if idx==len(first_outcome_evs)-1:  # don't need upper bound on time, since last outcome event:
            tmp_success_ev = [i for i in success_evs if i.time > oev.time]
            tmp_fail_ev = [i for i in fail_evs if i.time > oev.time]
            tmp_ignore_ev = [i for i in ignore_evs if i.time > oev.time]
        else:
            tmp_success_ev = [i for i in success_evs if i.time > oev.time and i.time < first_outcome_evs[idx+1].time]
            tmp_fail_ev = [i for i in fail_evs if i.time > oev.time and i.time < first_outcome_evs[idx+1].time]
            tmp_ignore_ev = [i for i in ignore_evs if i.time > oev.time and i.time < first_outcome_evs[idx+1].time]
        #print [len(tmp_success_ev), len(tmp_fail_ev), len(tmp_ignore_ev)]
        tmp_result_evs = [tmp_success_ev, tmp_fail_ev, tmp_ignore_ev]
        tmp_result_evs = [i[0] for i in tmp_result_evs if len(i)>0] # only take the first occurrence
        result_times = [(idx, i.time) for idx,i in enumerate(tmp_result_evs) if len(i)>0]  # get the time-stamps of first response in each type recorded
        result_idx = [ev for ev in result_times if ev[1]==min([i[1] for i in result_times])][0] # get the first response given
        result_ev = tmp_result_evs[result_idx[0]]
        result_events.append(result_ev)
    print "N first-outcomes found: ", len(first_outcome_evs)
    print "N outcomes (final): ", len(result_events)
    
    return result_events

# %%
# Set data-paths:
prepend = '/' #'/Users/julianarhee'
source_dir = 'nas/volume1/behavior/data/mworks-data/head_fixed'
experiment = 'gratings'
version = 'v1'
nanimals = 4

data_dir = os.path.join(prepend, source_dir, experiment, version)
tmp_fns = os.listdir(data_dir)
fns = [f for f in tmp_fns if f.endswith('.mwk') and os.path.isfile(os.path.join(data_dir, f))]
print "Found %i MW data files." % len(fns)

version_output = '%s_output' % version
output_dir = os.path.join(prepend, source_dir, experiment, version_output)
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
# Out:
# Found 28 MW data files.

# %%
session_dates = list(set([f[:-4].split('_')[0] for f in fns]))
print "Sessions: ", session_dates

animal_names = list(set([f[:-4].split('_')[1] for f in fns]))
if len(animal_names)>nanimals:
    print "More than %i expected IDs found:" % nanimals
    for a,name in enumerate(animal_names):
        print a, ": ", name
    discard = raw_input("Enter idx of repeat names:\n")
    if len(discard)>0:
        discard = int(discard)
        print "Removing ID: %s" % animal_names[discard]
        animal_names.pop(discard)

print "Animals: ", animal_names
# Out:
# Sessions:  ['20170808', '20170806', '20170807', '20170804', '20170805', '20170802', '20170803']
# More than 4 expected IDs found:
# 0 :  Minerva
# 1 :  Hera
# 2 :  Athena
# 3 :  Juno
# 4 :  Juno2
# Enter idx of repeat names:
# 4
# Removing ID: Juno2
# Animals:  ['Minerva', 'Hera', 'Athena', 'Juno']

# %%
# Create dict of data for all animals and sessions:
datafiles = dict()
for animal in animal_names:
    animal_files = [f for f in fns if animal in f]
    datafiles[animal] = dict((session, dict()) for session in session_dates)
    for session in datafiles[animal].keys():
        session_files = [os.path.join(data_dir, f) for f in animal_files if session in f]
        if len(session_files)==0:
            datafiles[animal].pop(session, None)
        else:
            datafiles[animal][session]['files'] = session_files
datafiles
# Out:
# {'Athena': {'20170802': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170802_Athena.mwk']},
#   '20170803': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170803_Athena.mwk']},
#   '20170804': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170804_Athena.mwk']},
#   '20170805': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170805_Athena.mwk']},
#   '20170806': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170806_Athena.mwk']},
#   '20170807': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170807_Athena.mwk']},
#   '20170808': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170808_Athena.mwk']}},
#  'Hera': {'20170802': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170802_Hera.mwk']},
#   '20170803': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170803_Hera.mwk']},
#   '20170804': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170804_Hera.mwk']},
#   '20170805': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170805_Hera.mwk']},
#   '20170806': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170806_Hera.mwk']},
#   '20170807': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170807_Hera.mwk']},
#   '20170808': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170808_Hera.mwk']}},
#  'Juno': {'20170802': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170802_Juno.mwk']},
#   '20170803': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170803_Juno.mwk']},
#   '20170804': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170804_Juno.mwk',
#     '/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170804_Juno2.mwk']},
#   '20170805': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170805_Juno.mwk']},
#   '20170806': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170806_Juno.mwk']},
#   '20170807': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170807_Juno.mwk']},
#   '20170808': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170808_Juno.mwk']}},
#  'Minerva': {'20170802': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170802_Minerva.mwk']},
#   '20170803': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170803_Minerva.mwk']},
#   '20170805': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170805_Minerva.mwk']},
#   '20170806': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170806_Minerva.mwk']},
#   '20170807': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170807_Minerva.mwk']},
#   '20170808': {'files': ['/nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170808_Minerva.mwk']}}}

# %%
# Check if data dict exists.  If not, create new.  If yes, load and append:
output_files = [i for i in os.listdir(output_dir) if version in i and i.endswith('parsed_trials.pkl')]
if len(output_files)>0:
    data_fn = output_files[0]
    print "Found previous output file. Loading: %s" % data_fn
    with open(os.path.join(output_dir, data_fn), 'rb') as f:
        data = pkl.load(f)
else:
    print "No previous output file found. Creating new."
    data = dict((animal, dict((session, dict()) for session in sorted(datafiles[animal].keys()))) for animal in animal_names)
    
print data.keys()
# Out:
# Found previous output file. Loading: v1_parsed_trials.pkl
# ['Minerva', 'Hera', 'Juno', 'Athena']

# %%
# Out:
# ['20170808', '20170806', '20170807', '20170805', '20170802', '20170803']

# %%
# Remove old datafiles, don't need to reprocess:
for animal in data.keys():
    previous_sessions = sorted(data[animal].keys())
    new_sessions = sorted([k for k in datafiles[animal].keys() if k not in previous_sessions])
    print "Found new sessions: "
    for s,sid in enumerate(new_sessions):
        print s, sid
# Out:
# Found new sessions:
# Found new sessions:
# Found new sessions:
# Found new sessions:

# %%
# animal = data.keys()[0]
# session = data[animal].keys()[0]
# files = datafiles[animal][session]['files']
# print files

# f = files[0]

# df, bounds = get_session_bounds(f)

# %%
# # Determine state of training flags:
# t_boundary = bounds[0]
# pre_reward_evs = df.get_events('flag_pre_reward')
# pre_reward_evs = [i for i in pre_reward_evs if i.time>= t_boundary[0] and i.time<=t_boundary[1]]
# prereward_flag = [(ev.time, ev.value) for ev in pre_reward_evs]
# print prereward_flag

# guarantee_reward_evs = df.get_events('flag_guarantee_reward')
# guarantee_reward_evs = [i for i in guarantee_reward_evs if i.time>=t_boundary[0] and i.time<=t_boundary[1]]
# guarantee_flag = [(ev.time, ev.value) for ev in guarantee_reward_evs]
# print guarantee_flag

# %%
# Look at specific animal datafile:
#animal = datafiles.keys()[2]
for animal in datafiles.keys():
    for session in sorted(new_sessions): #sorted(datafiles[animal].keys()):
        # session = sorted(datafiles[animal].keys())[2]

        print "Current session: ", session
        data[animal][session] = dict()

        files = datafiles[animal][session]['files']

        data[animal][session]['trials'] = []
        data[animal][session]['image_events'] = []
        data[animal][session]['result_events'] = []
        data[animal][session]['abort_events'] = []
        outcome_types = ['nsuccess', 'nfail', 'nignore', 'ntrials']
        data[animal][session]['performance'] = dict((outcome_type, 0) for outcome_type in outcome_types)
        data[animal][session]['performance']['unknown'] = [] 

        for fidx,f in enumerate(files):

            # ------------------------------------------------------------
            # Get session boundaries from file:
            # ------------------------------------------------------------
            df, bounds = get_session_bounds(f)
            t_boundary = bounds[0]

            if fidx==0:
                data[animal][session]['start_time'] = t_boundary[0]
                data[animal][session]['end_time'] = t_boundary[1]
            else:
                if t_boundary[0] < data[animal][session]['start_time']:
                    # 2nd processed file actually occurred earlier in time
                    data[animal][session]['start_time'] = t_boundary[0]
                    append_before = True
                else:
                    data[animal][session]['end_time'] = t_boundary[1]
                    append_before = False

            # ------------------------------------------------------------
            # Get session info:
            # ------------------------------------------------------------
            session_info = get_session_info(df)
            print session_info
            if not 'info' in data[animal][session].keys():
                data[animal][session]['info'] = session_info

            # ------------------------------------------------------------
            # Get training info:
            # ------------------------------------------------------------
            pre_reward_evs = df.get_events('flag_pre_reward')
            pre_reward_evs = [i for i in pre_reward_evs if i.time>= t_boundary[0] and i.time<=t_boundary[1]]
            # print prereward_flag
            guarantee_reward_evs = df.get_events('flag_guarantee_reward')
            guarantee_reward_evs = [i for i in guarantee_reward_evs if i.time>=t_boundary[0] and i.time<=t_boundary[1]]
            # print guarantee_flag
            if sum([ev.value for ev in pre_reward_evs])>0:
                check_prereward = True
            else:
                check_prereward = False
            if sum([ev.value for ev in guarantee_reward_evs])>0:
                check_guarantee = True
            else:
                check_guarantee = False

            # ------------------------------------------------------------
            # Get all trials (and stimulu-ITI events):
            # ------------------------------------------------------------
            image_events, all_trial_events, abort_events = get_image_events(df, t_boundary, stimtype='grating')

            # Get ITI events and check them:
            iti_events = [ev for ev in all_trial_events[1::2]]

            incorrect_iti = [idx for idx,i in enumerate(iti_events) if len(i.value)>1]
            if len(incorrect_iti)>0:
                print "Found %i incorrect blank-screen ITIs..." % len(incorrect_iti)
                print incorrect_iti

            # If no "blank" period after image, experiment ended mid-stimulus, so remove:
            if len(image_events)*2 > len(all_trial_events):
                image_events.pop(-1)
            print "N trials: ", len(image_events)
            print "N trial epochs: ",  len(all_trial_events)

            # Filter out any non-outcome trials:
            iti_events = [ev for ev in all_trial_events[1::2]]
            print "n imagess: ", len(image_events)
            print "n itis: ", len(iti_events)


            # ------------------------------------------------------------
            # Get all RESPONSE events:
            # ------------------------------------------------------------
            outcome_reached_evs = df.get_events('outcome_reached')
            found_outcome_evs = []
            for idx,(im,iti) in enumerate(zip(image_events, iti_events)):
                next_outcome = [i for i in outcome_reached_evs if i.time>im.time and i.time<iti.time and i.value==1]
                found_outcome_evs.append(next_outcome)

            print "N outcomes found: ", len(found_outcome_evs)

            # Before 08/03, all animals except (Athena?) ran on protocol that did not properly reset "trial_aborted" flag
            # This means that some new-stimulus events could be "aborted" trials that are not caught by the aborted-trial flag.
            # If no outcome is reached between new-stimulus events in image_events (and all_trial_events), additionally remove those:
            print "N new-stimulus trial starts: ", len(image_events)
            if len(found_outcome_evs)!=len(image_events):
                print "Mismatch in N outcomes and N image-events found."

            # Check for extra aborts:
            extra_aborts = [idx for idx,ev in enumerate(found_outcome_evs) if len(ev)==0]
            if len(extra_aborts)>0:
                print "Found %i additional aborted trials (no outcome reached after stimulus shown)." % len(extra_aborts)
                print extra_aborts

            if session=='20170802' or len(extra_aborts)>0:
                print "Removing additional trial-abort events."
                if len(found_outcome_evs)==len(image_events):
                    # Remove extra aborts from result-evs and image-evs:
                    found_outcome_evs = [ev for idx,ev in enumerate(found_outcome_evs) if idx not in extra_aborts]
                    image_events = [ev for idx,ev in enumerate(image_events) if idx not in extra_aborts]
                    extra_aborted_events = [ev for idx,ev in enumerate(image_events) if idx in extra_aborts]
                    abort_events.append(extra_aborted_events)
                    abort_events = [item for sublist in abort_events for item in sublist]

                    # Also remove from all-trial-epochs list:
                    extra_aborts_all_epochs = [[i*2, i*2+1] for i in extra_aborts]
                    extra_aborts_all_epochs = [item for sublist in extra_aborts_all_epochs for item in sublist]
                    all_trial_events = [ev for idx,ev in enumerate(all_trial_events) if idx not in extra_aborts_all_epochs]

            #print len(image_events)
            #print len(found_outcome_evs)

            # ------------------------------------------------------------
            # Get animal's FIRST response:
            # ------------------------------------------------------------
            # Since training flags influence which and how many outcomes are possible on each trial, need to distinguish:
            # first response from all responses. For example, an initial "ignore" or "fail" trial can still have a "success"
            # if training flag flag_guarantee_reward is on.
            result_events = get_first_response(found_outcome_evs)

            # ------------------------------------------------------------
            # Assign FIRST outcome to each trial:
            # ------------------------------------------------------------
            # tmp_trial_events = pymworks.events.display.to_trials(image_events, result_evs, duration_multiplier=1, remove_unknown=False)
            triallist = to_trials(image_events, result_events, duration_multiplier=None,remove_unknown=False)
                
            print "N result events: ", len(result_events)
            print "N trial events: ", len(triallist)
            mismatch = []
            for idx,(res,tri) in enumerate(zip(result_events, triallist[0:len(result_events)])):
                if not res.name==tri['outcome']:
                    mismatch.append(idx)
            if len(mismatch)>0:
                print "-----------------------WARNING_--------------------------"
                print "---------------------------------------------------------"
                print "Bad stimulus-to-response alignment. Check pymworks functions or -duration- arugment to to_trials()."
                print "Found %i mismatches, starting at index %i." % (len(mismatch), mismatch[0])
                print "---------------------------------------------------------"
            
            # ------------------------------------------------------------
            # Check training flags, if needed:
            # ------------------------------------------------------------
            if check_prereward:
                prereward_on = [i.time for i in pre_reward_evs if i.value==1]
                prereward_off = [i.time for i in pre_reward_evs if i.value==0 and i.time>min(prereward_on)]
                if len(prereward_off)==0 and len(prereward_on)>0:
                    prereward_off.append(t_boundary[1])
                print "pre-reward ON (s): ", (max(prereward_off)-min(prereward_on))/1E6
                for t in triallist:
                    if t['time']<=max(prereward_off) and i['time']>=min(prereward_on):
                        t['prereward'] = 1
                    else:
                        t['prereward'] = 0
            else:
                for t in triallist:
                    t['prereward'] = 0
            if check_guarantee:
                guarantee_on = [i.time for i in guarantee_reward_evs if i.value==1]
                guarantee_off = [i.time for i in guarantee_reward_evs if i.value==0]
                #if min(guarantee_on)
                if len(guarantee_off)==0 and len(guarantee_on)>0:
                    guarantee_off.append(t_boundary[1])
                print "guarantee ON (s): ", (max(guarantee_off)-min(guarantee_on))/1E6
                for t in triallist:
                    if t['time']<=max(guarantee_off) and i['time']>=min(guarantee_on):
                        t['guarantee'] = 1
                    else:
                        t['guarantee'] = 0
            else:
                for t in triallist:
                    t['guarantee'] = 0
            print triallist[0]
            
            # ------------------------------------------------------------
            # Store event info:
            # ------------------------------------------------------------
            #if 'trials' in data[animal][session].keys():
            data[animal][session]['trials'].append(triallist)
            data[animal][session]['image_events'].append(image_events)
            data[animal][session]['result_events'].append(result_events)
            data[animal][session]['abort_events'].append(abort_events)

            # ------------------------------------------------------------
            # Tally up each outcome type:
            # ------------------------------------------------------------
            unknown = []
            nsuccess = 0; nfail = 0; nignore = 0; ntrials = 0
            for idx,t in enumerate(triallist):
                ntrials += 1
                if 'success' in t['outcome']:
                    nsuccess += 1
                elif 'fail' in t['outcome']:
                    nfail += 1
                elif 'ignore' in t['outcome']:
                    nignore += 1
                else:
                    unknown.append(idx)
                    

            data[animal][session]['performance']['ntrials'] += ntrials
            data[animal][session]['performance']['nsuccess'] += nsuccess
            data[animal][session]['performance']['nfail'] += nfail
            data[animal][session]['performance']['nignore'] += nignore
            data[animal][session]['performance']['unknown'] = data[animal][session]['performance']['unknown'] + unknown

        # Flatten and sort lists by time:
        if f>1:
            if len(triallist)>0:
                data[animal][session]['trials'] = sorted([item for sublist in data[animal][session]['trials'] for item in sublist], key=lambda e: e['time'])
            if len(image_events)>0:
                data[animal][session]['image_events'] = sorted([item for sublist in data[animal][session]['image_events'] for item in sublist], key=lambda e: e.time)
            if len(result_events)>0:
                data[animal][session]['result_events']= sorted([item for sublist in data[animal][session]['result_events'] for item in sublist], key=lambda e: e.time)
            if len(abort_events)>0:
                data[animal][session]['abort_events'] = sorted([item for sublist in data[animal][session]['abort_events'] for item in sublist], key=lambda e: e.time)
        #     print "N successes: ", nsuccess
        #     print "N fails: ", nfail
        #     print "N ignores: ", nignore
        #     print "N trials: ", ntrials
# Out:
# Current session:  20170802
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170802_Minerva.mwk...
# Found 1 start events in session.
# Bounds:  [[3180770839, 7053242064]]
# bound ID: 0 3872.471225 sec
# ****************************************************************
# {'A_port': 1, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 553
# N image evs after taking only first image:  517
# N aborted images:  0
# N image evs after removing aborted:  517
# got iti events
# Length of trial epochs:  1034
# Number of trials found:  517
# N trials:  517
# N trial epochs:  1034
# n imagess:  517
# n itis:  517
# N outcomes found:  517
# N new-stimulus trial starts:  517
# Found 1 additional aborted trials (no outcome reached after stimulus shown).
# [305]
# Removing additional trial-abort events.
# N first-outcomes found:  516
# N outcomes (final):  516
# N result events:  516
# N trial events:  516
# pre-reward ON (s):  901.787148
# guarantee ON (s):  3872.459756
# {'direction': 0, 'start_time': 3183562248, 'time': 3183578915, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 0, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 1, 'name': 'fullscreen_vertical_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 3184054453, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_successes_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170803
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170803_Minerva.mwk...
# Found 1 start events in session.
# Bounds:  [[87393573863, 91054812488]]
# bound ID: 0 3661.238625 sec
# ****************************************************************
# {'A_port': 1, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 442
# N image evs after taking only first image:  359
# N aborted images:  0
# N image evs after removing aborted:  359
# got iti events
# Length of trial epochs:  718
# Number of trials found:  359
# N trials:  359
# N trial epochs:  718
# n imagess:  359
# n itis:  359
# N outcomes found:  359
# N new-stimulus trial starts:  359
# N first-outcomes found:  359
# N outcomes (final):  359
# N result events:  359
# N trial events:  359
# guarantee ON (s):  3661.229929
# {'direction': 0, 'start_time': 87396380960, 'time': 87396397627, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 0, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 0, 'name': 'fullscreen_vertical_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 87398368875, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_ignores_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170804
# Current session:  20170805
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170805_Minerva.mwk...
# Found 1 start events in session.
# Bounds:  [[66522679, 4659985413]]
# bound ID: 0 4593.462734 sec
# ****************************************************************
# {'A_port': 1, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 686
# N image evs after taking only first image:  603
# N aborted images:  0
# N image evs after removing aborted:  603
# got iti events
# Length of trial epochs:  1206
# Number of trials found:  603
# N trials:  603
# N trial epochs:  1206
# n imagess:  603
# n itis:  603
# N outcomes found:  603
# N new-stimulus trial starts:  603
# N first-outcomes found:  603
# N outcomes (final):  603
# N result events:  603
# N trial events:  603
# pre-reward ON (s):  210.070204
# guarantee ON (s):  4593.454886
# {'direction': 0, 'start_time': 69160944, 'time': 69177611, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 90, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 1, 'name': 'fullscreen_horizontal_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 71147565, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_ignores_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170806
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170806_Minerva.mwk...
# Found 1 start events in session.
# Bounds:  [[85004356074, 89838739936]]
# bound ID: 0 4834.383862 sec
# ****************************************************************
# {'A_port': 1, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 707
# N image evs after taking only first image:  400
# N aborted images:  0
# N image evs after removing aborted:  400
# got iti events
# Length of trial epochs:  800
# Number of trials found:  400
# N trials:  400
# N trial epochs:  800
# n imagess:  400
# n itis:  400
# N outcomes found:  400
# N new-stimulus trial starts:  400
# Found 6 additional aborted trials (no outcome reached after stimulus shown).
# [40, 208, 320, 341, 352, 355]
# Removing additional trial-abort events.
# N first-outcomes found:  394
# N outcomes (final):  394
# N result events:  394
# N trial events:  394
# pre-reward ON (s):  109.591028
# guarantee ON (s):  4834.374518
# {'direction': 0, 'start_time': 85007113011, 'time': 85007129678, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 0, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 1, 'name': 'fullscreen_vertical_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 85009100373, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_ignores_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170807
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170807_Minerva.mwk...
# Found 1 start events in session.
# Bounds:  [[170903349942, 174508681403]]
# bound ID: 0 3605.331461 sec
# ****************************************************************
# {'A_port': 1, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 481
# N image evs after taking only first image:  287
# N aborted images:  0
# N image evs after removing aborted:  287
# got iti events
# Length of trial epochs:  574
# Number of trials found:  287
# N trials:  287
# N trial epochs:  574
# n imagess:  287
# n itis:  287
# N outcomes found:  287
# N new-stimulus trial starts:  287
# Found 4 additional aborted trials (no outcome reached after stimulus shown).
# [127, 216, 247, 264]
# Removing additional trial-abort events.
# N first-outcomes found:  283
# N outcomes (final):  283
# N result events:  283
# N trial events:  283
# guarantee ON (s):  3605.314639
# {'direction': 0, 'start_time': 170905898430, 'time': 170905915096, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 90, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 0, 'name': 'fullscreen_horizontal_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 170906737243, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_failures_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170808
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170808_Minerva.mwk...
# Found 1 start events in session.
# Bounds:  [[257266793217, 261988367757]]
# bound ID: 0 4721.57454 sec
# ****************************************************************
# {'A_port': 1, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 805
# N image evs after taking only first image:  572
# N aborted images:  0
# N image evs after removing aborted:  572
# got iti events
# Length of trial epochs:  1144
# Number of trials found:  572
# N trials:  572
# N trial epochs:  1144
# n imagess:  572
# n itis:  572
# N outcomes found:  572
# N new-stimulus trial starts:  572
# Found 10 additional aborted trials (no outcome reached after stimulus shown).
# [160, 165, 200, 297, 380, 394, 461, 476, 508, 519]
# Removing additional trial-abort events.
# N first-outcomes found:  562
# N outcomes (final):  562
# N result events:  562
# N trial events:  562
# {'direction': 0, 'start_time': 257272600532, 'time': 257272617199, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 90, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 0, 'prereward': 0, 'name': 'fullscreen_horizontal_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 257272995565, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_successes_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170802
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170802_Hera.mwk...
# Found 1 start events in session.
# Bounds:  [[19038498854, 22271668619]]
# bound ID: 0 3233.169765 sec
# ****************************************************************
# {'A_port': 1, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 495
# N image evs after taking only first image:  484
# N aborted images:  0
# N image evs after removing aborted:  484
# got iti events
# Length of trial epochs:  968
# Number of trials found:  484
# N trials:  484
# N trial epochs:  968
# n imagess:  484
# n itis:  484
# N outcomes found:  484
# N new-stimulus trial starts:  484
# Removing additional trial-abort events.
# N first-outcomes found:  484
# N outcomes (final):  484
# N result events:  484
# N trial events:  484
# pre-reward ON (s):  1000.886356
# guarantee ON (s):  3233.153007
# {'direction': 0, 'start_time': 19041162634, 'time': 19041179300, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 90, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 1, 'name': 'fullscreen_horizontal_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 19043148657, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_ignores_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170803
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170803_Hera.mwk...
# Found 1 start events in session.
# Bounds:  [[484745678, 3764745187]]
# bound ID: 0 3279.999509 sec
# ****************************************************************
# {'A_port': 1, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 366
# N image evs after taking only first image:  331
# N aborted images:  0
# N image evs after removing aborted:  331
# got iti events
# Length of trial epochs:  662
# Number of trials found:  331
# N trials:  331
# N trial epochs:  662
# n imagess:  331
# n itis:  331
# N outcomes found:  331
# N new-stimulus trial starts:  331
# N first-outcomes found:  331
# N outcomes (final):  331
# N result events:  331
# N trial events:  331
# pre-reward ON (s):  681.558738
# guarantee ON (s):  3279.992754
# {'direction': 0, 'start_time': 487416609, 'time': 487433276, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 90, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 1, 'name': 'fullscreen_horizontal_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 487923299, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_successes_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170804
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170804_Hera.mwk...
# Found 1 start events in session.
# Bounds:  [[76382841909, 79862004180]]
# bound ID: 0 3479.162271 sec
# ****************************************************************
# {'A_port': 1, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 384
# N image evs after taking only first image:  336
# N aborted images:  0
# N image evs after removing aborted:  336
# got iti events
# Length of trial epochs:  672
# Number of trials found:  336
# N trials:  336
# N trial epochs:  672
# n imagess:  336
# n itis:  336
# N outcomes found:  336
# N new-stimulus trial starts:  336
# Found 1 additional aborted trials (no outcome reached after stimulus shown).
# [217]
# Removing additional trial-abort events.
# N first-outcomes found:  335
# N outcomes (final):  335
# N result events:  335
# N trial events:  335
# pre-reward ON (s):  308.877078
# guarantee ON (s):  3479.148971
# {'direction': 0, 'start_time': 76388751786, 'time': 76388768453, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 90, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 1, 'name': 'fullscreen_horizontal_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 76390738028, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_ignores_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170805
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170805_Hera.mwk...
# Found 1 start events in session.
# Bounds:  [[22059594333, 26108802754]]
# bound ID: 0 4049.208421 sec
# ****************************************************************
# {'A_port': 1, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 520
# N image evs after taking only first image:  403
# N aborted images:  0
# N image evs after removing aborted:  403
# got iti events
# Length of trial epochs:  806
# Number of trials found:  403
# N trials:  403
# N trial epochs:  806
# n imagess:  403
# n itis:  403
# N outcomes found:  403
# N new-stimulus trial starts:  403
# Found 1 additional aborted trials (no outcome reached after stimulus shown).
# [136]
# Removing additional trial-abort events.
# N first-outcomes found:  402
# N outcomes (final):  402
# N result events:  402
# N trial events:  402
# pre-reward ON (s):  103.020232
# guarantee ON (s):  4049.189216
# {'direction': 0, 'start_time': 22063361504, 'time': 22063378171, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 90, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 1, 'name': 'fullscreen_horizontal_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 22063618135, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_successes_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170806
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170806_Hera.mwk...
# Found 1 start events in session.
# Bounds:  [[95081732049, 98988572243]]
# bound ID: 0 3906.840194 sec
# ****************************************************************
# {'A_port': 1, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 544
# N image evs after taking only first image:  505
# N aborted images:  0
# N image evs after removing aborted:  505
# got iti events
# Length of trial epochs:  1010
# Number of trials found:  505
# N trials:  505
# N trial epochs:  1010
# n imagess:  505
# n itis:  505
# N outcomes found:  505
# N new-stimulus trial starts:  505
# Found 1 additional aborted trials (no outcome reached after stimulus shown).
# [91]
# Removing additional trial-abort events.
# N first-outcomes found:  504
# N outcomes (final):  504
# N result events:  504
# N trial events:  504
# guarantee ON (s):  3906.822978
# {'direction': 0, 'start_time': 95084546585, 'time': 95084563252, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 0, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 0, 'name': 'fullscreen_vertical_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 95086533617, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_ignores_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170807
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170807_Hera.mwk...
# Found 1 start events in session.
# Bounds:  [[181328639216, 184339033613]]
# bound ID: 0 3010.394397 sec
# ****************************************************************
# {'A_port': 1, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 368
# N image evs after taking only first image:  230
# N aborted images:  0
# N image evs after removing aborted:  230
# got iti events
# Length of trial epochs:  460
# Number of trials found:  230
# N trials:  230
# N trial epochs:  460
# n imagess:  230
# n itis:  230
# N outcomes found:  230
# N new-stimulus trial starts:  230
# Found 2 additional aborted trials (no outcome reached after stimulus shown).
# [37, 65]
# Removing additional trial-abort events.
# N first-outcomes found:  228
# N outcomes (final):  228
# N result events:  228
# N trial events:  228
# guarantee ON (s):  3010.381927
# {'direction': 0, 'start_time': 181331248682, 'time': 181331265349, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 0, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 0, 'name': 'fullscreen_vertical_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 181331708304, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_failures_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170808
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170808_Hera.mwk...
# Found 1 start events in session.
# Bounds:  [[269138376163, 273746928037]]
# bound ID: 0 4608.551874 sec
# ****************************************************************
# {'A_port': 1, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 775
# N image evs after taking only first image:  734
# N aborted images:  0
# N image evs after removing aborted:  734
# got iti events
# Length of trial epochs:  1468
# Number of trials found:  734
# N trials:  734
# N trial epochs:  1468
# n imagess:  734
# n itis:  734
# N outcomes found:  734
# N new-stimulus trial starts:  734
# Found 3 additional aborted trials (no outcome reached after stimulus shown).
# [234, 373, 494]
# Removing additional trial-abort events.
# N first-outcomes found:  731
# N outcomes (final):  731
# N result events:  731
# N trial events:  731
# {'direction': 0, 'start_time': 269140950844, 'time': 269140967511, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 0, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 0, 'prereward': 0, 'name': 'fullscreen_vertical_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 269142937570, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_ignores_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170802
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170802_Juno.mwk...
# Found 1 start events in session.
# Bounds:  [[13485378593, 17571275469]]
# bound ID: 0 4085.896876 sec
# ****************************************************************
# {'A_port': 2, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 577
# N image evs after taking only first image:  558
# N aborted images:  0
# N image evs after removing aborted:  558
# got iti events
# Length of trial epochs:  1116
# Number of trials found:  558
# N trials:  558
# N trial epochs:  1116
# n imagess:  558
# n itis:  558
# N outcomes found:  558
# N new-stimulus trial starts:  558
# Removing additional trial-abort events.
# N first-outcomes found:  558
# N outcomes (final):  558
# N result events:  558
# N trial events:  558
# pre-reward ON (s):  1540.65168
# guarantee ON (s):  4085.877356
# {'direction': 0, 'start_time': 13490979166, 'time': 13490995833, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 90, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 1, 'name': 'fullscreen_horizontal_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 13492965688, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_ignores_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170803
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170803_Juno.mwk...
# Found 1 start events in session.
# Bounds:  [[94070965475, 98532753882]]
# bound ID: 0 4461.788407 sec
# ****************************************************************
# {'A_port': 2, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 663
# N image evs after taking only first image:  637
# N aborted images:  0
# N image evs after removing aborted:  637
# got iti events
# Length of trial epochs:  1274
# Number of trials found:  637
# N trials:  637
# N trial epochs:  1274
# n imagess:  637
# n itis:  637
# N outcomes found:  637
# N new-stimulus trial starts:  637
# Found 2 additional aborted trials (no outcome reached after stimulus shown).
# [314, 385]
# Removing additional trial-abort events.
# N first-outcomes found:  635
# N outcomes (final):  635
# N result events:  635
# N trial events:  635
# pre-reward ON (s):  111.496443
# guarantee ON (s):  4461.770565
# {'direction': 0, 'start_time': 94073514452, 'time': 94073531119, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 0, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 1, 'name': 'fullscreen_vertical_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 94075501084, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_ignores_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170804
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170804_Juno.mwk...
# Found 1 start events in session.
# Bounds:  [[68274202201, 68972179923]]
# bound ID: 0 697.977722 sec
# ****************************************************************
# {'A_port': 2, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 102
# N image evs after taking only first image:  97
# N aborted images:  0
# N image evs after removing aborted:  97
# got iti events
# Length of trial epochs:  194
# Number of trials found:  97
# N trials:  97
# N trial epochs:  194
# n imagess:  97
# n itis:  97
# N outcomes found:  97
# N new-stimulus trial starts:  97
# N first-outcomes found:  97
# N outcomes (final):  97
# N result events:  97
# N trial events:  97
# pre-reward ON (s):  15.482841
# guarantee ON (s):  697.960455
# {'direction': 0, 'start_time': 68276751590, 'time': 68276768255, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 90, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 1, 'name': 'fullscreen_horizontal_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 68278740154, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_ignores_session', 'type': 'drifting_grating', 'starting_phase': 0}
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170804_Juno2.mwk...
# Found 1 start events in session.
# Bounds:  [[68997169704, 72572005681]]
# bound ID: 0 3574.835977 sec
# ****************************************************************
# {'A_port': 2, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 535
# N image evs after taking only first image:  520
# N aborted images:  0
# N image evs after removing aborted:  520
# got iti events
# Length of trial epochs:  1040
# Number of trials found:  520
# N trials:  520
# N trial epochs:  1040
# n imagess:  520
# n itis:  520
# N outcomes found:  520
# N new-stimulus trial starts:  520
# N first-outcomes found:  520
# N outcomes (final):  520
# N result events:  520
# N trial events:  520
# guarantee ON (s):  3574.818442
# {'direction': 0, 'start_time': 68999984944, 'time': 69000001610, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 0, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 0, 'name': 'fullscreen_vertical_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 69001971893, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_ignores_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170805
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170805_Juno.mwk...
# Found 1 start events in session.
# Bounds:  [[5728538426, 10012371756]]
# bound ID: 0 4283.83333 sec
# ****************************************************************
# {'A_port': 2, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 544
# N image evs after taking only first image:  412
# N aborted images:  0
# N image evs after removing aborted:  412
# got iti events
# Length of trial epochs:  824
# Number of trials found:  412
# N trials:  412
# N trial epochs:  824
# n imagess:  412
# n itis:  412
# N outcomes found:  412
# N new-stimulus trial starts:  412
# Found 2 additional aborted trials (no outcome reached after stimulus shown).
# [283, 319]
# Removing additional trial-abort events.
# N first-outcomes found:  410
# N outcomes (final):  410
# N result events:  410
# N trial events:  410
# pre-reward ON (s):  277.430898
# guarantee ON (s):  4283.825431
# {'direction': 0, 'start_time': 5731227745, 'time': 5731244411, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 90, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 1, 'name': 'fullscreen_horizontal_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 5731807111, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_successes_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170806
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170806_Juno.mwk...
# Found 1 start events in session.
# Bounds:  [[90283052707, 94667348638]]
# bound ID: 0 4384.295931 sec
# ****************************************************************
# {'A_port': 2, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 633
# N image evs after taking only first image:  389
# N aborted images:  0
# N image evs after removing aborted:  389
# got iti events
# Length of trial epochs:  778
# Number of trials found:  389
# N trials:  389
# N trial epochs:  778
# n imagess:  389
# n itis:  389
# N outcomes found:  389
# N new-stimulus trial starts:  389
# Found 10 additional aborted trials (no outcome reached after stimulus shown).
# [56, 63, 70, 77, 85, 175, 220, 231, 270, 357]
# Removing additional trial-abort events.
# N first-outcomes found:  379
# N outcomes (final):  379
# N result events:  379
# N trial events:  379
# guarantee ON (s):  4384.283018
# {'direction': 0, 'start_time': 90288596467, 'time': 90288613134, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 0, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 0, 'name': 'fullscreen_vertical_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 90290582560, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_ignores_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170807
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170807_Juno.mwk...
# Found 1 start events in session.
# Bounds:  [[176409232656, 179725245694]]
# bound ID: 0 3316.013038 sec
# ****************************************************************
# {'A_port': 2, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 463
# N image evs after taking only first image:  226
# N aborted images:  0
# N image evs after removing aborted:  226
# got iti events
# Length of trial epochs:  452
# Number of trials found:  226
# N trials:  226
# N trial epochs:  452
# n imagess:  226
# n itis:  226
# N outcomes found:  226
# N new-stimulus trial starts:  226
# Found 9 additional aborted trials (no outcome reached after stimulus shown).
# [31, 56, 58, 76, 111, 120, 134, 140, 143]
# Removing additional trial-abort events.
# N first-outcomes found:  217
# N outcomes (final):  217
# N result events:  217
# N trial events:  217
# guarantee ON (s):  3315.994841
# {'direction': 0, 'start_time': 176414198568, 'time': 176414215235, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 90, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 0, 'name': 'fullscreen_horizontal_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 176416184737, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_ignores_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170808
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170808_Juno.mwk...
# Found 1 start events in session.
# Bounds:  [[263435507727, 268362274743]]
# bound ID: 0 4926.767016 sec
# ****************************************************************
# {'A_port': 2, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 887
# N image evs after taking only first image:  617
# N aborted images:  0
# N image evs after removing aborted:  617
# got iti events
# Length of trial epochs:  1234
# Number of trials found:  617
# N trials:  617
# N trial epochs:  1234
# n imagess:  617
# n itis:  617
# N outcomes found:  617
# N new-stimulus trial starts:  617
# Found 12 additional aborted trials (no outcome reached after stimulus shown).
# [43, 86, 101, 116, 140, 150, 285, 353, 424, 446, 478, 517]
# Removing additional trial-abort events.
# N first-outcomes found:  605
# N outcomes (final):  605
# N result events:  605
# N trial events:  605
# {'direction': 0, 'start_time': 263443050676, 'time': 263443067342, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 90, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 0, 'prereward': 0, 'name': 'fullscreen_horizontal_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 263443330523, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_successes_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170802
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170802_Athena.mwk...
# Found 1 start events in session.
# Bounds:  [[23964298890, 27793002489]]
# bound ID: 0 3828.703599 sec
# ****************************************************************
# {'A_port': 2, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 397
# N image evs after taking only first image:  326
# N aborted images:  0
# N image evs after removing aborted:  326
# got iti events
# Length of trial epochs:  652
# Number of trials found:  326
# N trials:  326
# N trial epochs:  652
# n imagess:  326
# n itis:  326
# N outcomes found:  326
# N new-stimulus trial starts:  326
# Found 2 additional aborted trials (no outcome reached after stimulus shown).
# [45, 189]
# Removing additional trial-abort events.
# N first-outcomes found:  324
# N outcomes (final):  324
# N result events:  324
# N trial events:  324
# pre-reward ON (s):  3828.687865
# guarantee ON (s):  3828.687868
# {'direction': 0, 'start_time': 23967129420, 'time': 23967146086, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 0, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 1, 'name': 'fullscreen_vertical_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 23969115935, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_ignores_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170803
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170803_Athena.mwk...
# Found 1 start events in session.
# Bounds:  [[5810104898, 11112920322]]
# bound ID: 0 5302.815424 sec
# ****************************************************************
# {'A_port': 2, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 682
# N image evs after taking only first image:  597
# N aborted images:  0
# N image evs after removing aborted:  597
# got iti events
# Length of trial epochs:  1194
# Number of trials found:  597
# N trials:  597
# N trial epochs:  1194
# n imagess:  597
# n itis:  597
# N outcomes found:  597
# N new-stimulus trial starts:  597
# Found 1 additional aborted trials (no outcome reached after stimulus shown).
# [317]
# Removing additional trial-abort events.
# N first-outcomes found:  596
# N outcomes (final):  596
# N result events:  596
# N trial events:  596
# pre-reward ON (s):  956.384506
# guarantee ON (s):  5302.800571
# {'direction': 0, 'start_time': 5813900099, 'time': 5813916766, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 0, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 1, 'name': 'fullscreen_vertical_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 5814072457, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_successes_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170804
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170804_Athena.mwk...
# Found 1 start events in session.
# Bounds:  [[487226972, 4131642192]]
# bound ID: 0 3644.41522 sec
# ****************************************************************
# {'A_port': 2, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 498
# N image evs after taking only first image:  468
# N aborted images:  0
# N image evs after removing aborted:  468
# got iti events
# Length of trial epochs:  936
# Number of trials found:  468
# N trials:  468
# N trial epochs:  936
# n imagess:  468
# n itis:  468
# N outcomes found:  468
# N new-stimulus trial starts:  468
# N first-outcomes found:  468
# N outcomes (final):  468
# N result events:  468
# N trial events:  468
# pre-reward ON (s):  718.622988
# guarantee ON (s):  3644.406594
# {'direction': 0, 'start_time': 490032863, 'time': 490049529, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 90, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 1, 'name': 'fullscreen_horizontal_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 490200243, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_successes_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170805
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170805_Athena.mwk...
# Found 1 start events in session.
# Bounds:  [[27111155417, 31630306452]]
# bound ID: 0 4519.151035 sec
# ****************************************************************
# {'A_port': 2, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 631
# N image evs after taking only first image:  458
# N aborted images:  0
# N image evs after removing aborted:  458
# got iti events
# Length of trial epochs:  916
# Number of trials found:  458
# N trials:  458
# N trial epochs:  916
# n imagess:  458
# n itis:  458
# N outcomes found:  458
# N new-stimulus trial starts:  458
# Found 2 additional aborted trials (no outcome reached after stimulus shown).
# [16, 447]
# Removing additional trial-abort events.
# N first-outcomes found:  456
# N outcomes (final):  456
# N result events:  456
# N trial events:  456
# pre-reward ON (s):  69.869909
# guarantee ON (s):  4519.142589
# {'direction': 0, 'start_time': 27113928256, 'time': 27113944923, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 90, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 1, 'name': 'fullscreen_horizontal_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 27114082740, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_successes_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170806
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170806_Athena.mwk...
# Found 1 start events in session.
# Bounds:  [[99499341691, 105818404940]]
# bound ID: 0 6319.063249 sec
# ****************************************************************
# {'A_port': 2, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 937
# N image evs after taking only first image:  751
# N aborted images:  0
# N image evs after removing aborted:  751
# got iti events
# Length of trial epochs:  1502
# Number of trials found:  751
# N trials:  751
# N trial epochs:  1502
# n imagess:  751
# n itis:  751
# N outcomes found:  751
# N new-stimulus trial starts:  751
# Found 2 additional aborted trials (no outcome reached after stimulus shown).
# [83, 131]
# Removing additional trial-abort events.
# N first-outcomes found:  749
# N outcomes (final):  749
# N result events:  749
# N trial events:  749
# guarantee ON (s):  6319.055301
# {'direction': 0, 'start_time': 99501963358, 'time': 99501980025, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 90, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 0, 'name': 'fullscreen_horizontal_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 99503949798, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_ignores_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170807
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170807_Athena.mwk...
# Found 1 start events in session.
# Bounds:  [[185628390225, 190002782056]]
# bound ID: 0 4374.391831 sec
# ****************************************************************
# {'A_port': 2, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 710
# N image evs after taking only first image:  595
# N aborted images:  0
# N image evs after removing aborted:  595
# got iti events
# Length of trial epochs:  1190
# Number of trials found:  595
# N trials:  595
# N trial epochs:  1190
# n imagess:  595
# n itis:  595
# N outcomes found:  595
# N new-stimulus trial starts:  595
# Found 7 additional aborted trials (no outcome reached after stimulus shown).
# [4, 21, 73, 468, 499, 557, 582]
# Removing additional trial-abort events.
# N first-outcomes found:  588
# N outcomes (final):  588
# N result events:  588
# N trial events:  588
# guarantee ON (s):  1396.165465
# {'direction': 0, 'start_time': 185631048799, 'time': 185631065465, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 90, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 1, 'prereward': 0, 'name': 'fullscreen_horizontal_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 185633035154, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_ignores_session', 'type': 'drifting_grating', 'starting_phase': 0}
# Current session:  20170808
# ****************************************************************
# Parsing file
# /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1/20170808_Athena.mwk...
# Found 1 start events in session.
# Bounds:  [[60904056, 4848503976]]
# bound ID: 0 4787.59992 sec
# ****************************************************************
# {'A_port': 2, 'stimsize': 100, 'stimulus_duration': 2000, 'iti_duration': 2000}
# No pixel clock.
# got image events
# N new-stimulus events: 833
# N image evs after taking only first image:  773
# N aborted images:  0
# N image evs after removing aborted:  773
# got iti events
# Length of trial epochs:  1546
# Number of trials found:  773
# N trials:  773
# N trial epochs:  1546
# n imagess:  773
# n itis:  773
# N outcomes found:  773
# N new-stimulus trial starts:  773
# Found 2 additional aborted trials (no outcome reached after stimulus shown).
# [82, 613]
# Removing additional trial-abort events.
# N first-outcomes found:  771
# N outcomes (final):  771
# N result events:  771
# N trial events:  771
# {'direction': 0, 'start_time': 63653944, 'time': 63670611, 'yoffset': 0, 'frequency': 0.06, 'duration': None, 'rotation': 90, 'height': 100, 'speed': 0, 'xoffset': 0, 'guarantee': 0, 'prereward': 0, 'name': 'fullscreen_horizontal_grating', 'current_phase': -0.0, 'mask': 'rectangle', 'width': 100, 'response_time': 65640285, 'alpha_multiplier': 1, 'grating': 'square', 'action': 'draw', 'outcome': 'n_ignores_session', 'type': 'drifting_grating', 'starting_phase': 0}

# %%
# Save processed data:
output_fn = '%s_parsed_trials.pkl' % version
with open(os.path.join(output_dir, output_fn), 'wb') as f:
    pkl.dump(data, f)

print "Saved output to: ", os.path.join(output_dir, output_fn)
# Out:
# Saved output to:  /nas/volume1/behavior/data/mworks-data/head_fixed/gratings/v1_output/v1_parsed_trials.pkl

# %%
# Plot overall performance:
from bokeh.io import gridplot

c_success = "navy"
c_fail = "firebrick"
c_ignore = "gray"
lwidth = 2
flagpos1 = 1.1; flagcol1 = "black";
flagpos2 = 1; flagcol2 = "black";
flagsize = 5

animal = data.keys()[0]
# create a new plot
ntrials = [data[animal][s]['performance']['ntrials'] for s in sorted(data[animal].keys())]
ncorrect = [data[animal][s]['performance']['nsuccess'] for s in sorted(data[animal].keys())]
nfail = [data[animal][s]['performance']['nfail'] for s in sorted(data[animal].keys())]
nignore = [data[animal][s]['performance']['nignore'] for s in sorted(data[animal].keys())]
nsessions = len(sorted(data[animal].keys()))
s1 = figure(width=250, plot_height=250, title=animal)
ncorrect = np.array([float(n) for n in ncorrect])/np.array([float(t) for t in ntrials])
nfail = np.array([float(n) for n in nfail])/np.array([float(t) for t in ntrials])
nignore = np.array([float(n) for n in nignore])/np.array([float(t) for t in ntrials])

s1.line(range(nsessions), ncorrect, line_width=lwidth, line_color=c_success, line_alpha=0.5)
s1.line(range(nsessions), nfail, line_width=lwidth, line_color=c_fail, line_alpha=0.5)
s1.line(range(nsessions), nignore, line_width=lwidth, line_color=c_ignore, line_alpha=0.5)

n_prereward_on = [sum(data[animal][s]['trials'][t]['prereward'] for t in range(len(data[animal][s]['trials']))) for s in sorted(data[animal].keys())]
n_guarantee_on = [sum(data[animal][s]['trials'][t]['guarantee'] for t in range(len(data[animal][s]['trials']))) for s in sorted(data[animal].keys())]
percent_prereward_on = np.array([float(n) for n in n_prereward_on])/np.array([float(n) for n in ntrials])
percent_guarantee_on = np.array([float(n) for n in n_guarantee_on])/np.array([float(n) for n in ntrials])
flag_prereward = [idx for idx,p in enumerate(percent_prereward_on) if p>0.5]
flag_guarantee = [idx for idx,p in enumerate(percent_guarantee_on) if p>0.5]
s1.circle(flag_prereward, np.ones((len(flag_prereward),))*flagpos1, size=flagsize, color=flagcol1, alpha=0.5)
s1.triangle(flag_guarantee, np.ones((len(flag_guarantee),))*flagpos2, size=flagsize, color=flagcol2, alpha=0.5)

# Create another plot:
animal = data.keys()[1]
# create a new plot
ntrials = [data[animal][s]['performance']['ntrials'] for s in sorted(data[animal].keys())]
ncorrect = [data[animal][s]['performance']['nsuccess'] for s in sorted(data[animal].keys())]
nfail = [data[animal][s]['performance']['nfail'] for s in sorted(data[animal].keys())]
nignore = [data[animal][s]['performance']['nignore'] for s in sorted(data[animal].keys())]
nsessions = len(sorted(data[animal].keys()))
n_prereward_on = [sum(data[animal][s]['trials'][t]['prereward'] for t in range(len(data[animal][s]['trials']))) for s in sorted(data[animal].keys())]
n_guarantee_on = [sum(data[animal][s]['trials'][t]['guarantee'] for t in range(len(data[animal][s]['trials']))) for s in sorted(data[animal].keys())]
percent_prereward_on = np.array([float(n) for n in n_prereward_on])/np.array([float(n) for n in ntrials])
percent_guarantee_on = np.array([float(n) for n in n_guarantee_on])/np.array([float(n) for n in ntrials])
flag_prereward = [idx for idx,p in enumerate(percent_prereward_on) if p>0.5]
flag_guarantee = [idx for idx,p in enumerate(percent_guarantee_on) if p>0.5]

s2 = figure(width=250, plot_height=250, title=animal)
ncorrect = np.array([float(n) for n in ncorrect])/np.array([float(t) for t in ntrials])
nfail = np.array([float(n) for n in nfail])/np.array([float(t) for t in ntrials])
nignore = np.array([float(n) for n in nignore])/np.array([float(t) for t in ntrials])
s2.line(range(nsessions), ncorrect, line_width=lwidth, line_color=c_success, line_alpha=0.5)
s2.line(range(nsessions), nfail, line_width=lwidth, line_color=c_fail, line_alpha=0.5)
s2.line(range(nsessions), nignore, line_width=lwidth, line_color=c_ignore, line_alpha=0.5)
s2.circle(flag_prereward, np.ones((len(flag_prereward),))*flagpos1, size=flagsize, color=flagcol1, alpha=0.5)
s2.triangle(flag_guarantee, np.ones((len(flag_guarantee),))*flagpos2, size=flagsize, color=flagcol2, alpha=0.5)


# Create another plot:
animal = data.keys()[2]
# create a new plot
ntrials = [data[animal][s]['performance']['ntrials'] for s in sorted(data[animal].keys())]
ncorrect = [data[animal][s]['performance']['nsuccess'] for s in sorted(data[animal].keys())]
nfail = [data[animal][s]['performance']['nfail'] for s in sorted(data[animal].keys())]
nignore = [data[animal][s]['performance']['nignore'] for s in sorted(data[animal].keys())]
nsessions = len(sorted(data[animal].keys()))
n_prereward_on = [sum(data[animal][s]['trials'][t]['prereward'] for t in range(len(data[animal][s]['trials']))) for s in sorted(data[animal].keys())]
n_guarantee_on = [sum(data[animal][s]['trials'][t]['guarantee'] for t in range(len(data[animal][s]['trials']))) for s in sorted(data[animal].keys())]
percent_prereward_on = np.array([float(n) for n in n_prereward_on])/np.array([float(n) for n in ntrials])
percent_guarantee_on = np.array([float(n) for n in n_guarantee_on])/np.array([float(n) for n in ntrials])
flag_prereward = [idx for idx,p in enumerate(percent_prereward_on) if p>0.5]
flag_guarantee = [idx for idx,p in enumerate(percent_guarantee_on) if p>0.5]

s3 = figure(width=250, plot_height=250, title=animal)
ncorrect = np.array([float(n) for n in ncorrect])/np.array([float(t) for t in ntrials])
nfail = np.array([float(n) for n in nfail])/np.array([float(t) for t in ntrials])
nignore = np.array([float(n) for n in nignore])/np.array([float(t) for t in ntrials])

s3.line(range(nsessions), ncorrect, line_width=lwidth, line_color=c_success, line_alpha=0.5)
s3.line(range(nsessions), nfail, line_width=lwidth, line_color=c_fail, line_alpha=0.5)
s3.line(range(nsessions), nignore, line_width=lwidth, line_color=c_ignore, line_alpha=0.5)
s3.circle(flag_prereward, np.ones((len(flag_prereward),))*flagpos1, size=flagsize, color=flagcol1, alpha=0.5)
s3.triangle(flag_guarantee, np.ones((len(flag_guarantee),))*flagpos2, size=flagsize, color=flagcol2, alpha=0.5)


# Create another plot:
animal = data.keys()[3]
# create a new plot
ntrials = [data[animal][s]['performance']['ntrials'] for s in sorted(data[animal].keys())]
ncorrect = [data[animal][s]['performance']['nsuccess'] for s in sorted(data[animal].keys())]
nfail = [data[animal][s]['performance']['nfail'] for s in sorted(data[animal].keys())]
nignore = [data[animal][s]['performance']['nignore'] for s in sorted(data[animal].keys())]
nsessions = len(sorted(data[animal].keys()))

n_prereward_on = [sum(data[animal][s]['trials'][t]['prereward'] for t in range(len(data[animal][s]['trials']))) for s in sorted(data[animal].keys())]
n_guarantee_on = [sum(data[animal][s]['trials'][t]['guarantee'] for t in range(len(data[animal][s]['trials']))) for s in sorted(data[animal].keys())]
percent_prereward_on = np.array([float(n) for n in n_prereward_on])/np.array([float(n) for n in ntrials])
percent_guarantee_on = np.array([float(n) for n in n_guarantee_on])/np.array([float(n) for n in ntrials])
flag_prereward = [idx for idx,p in enumerate(percent_prereward_on) if p>0.5]
flag_guarantee = [idx for idx,p in enumerate(percent_guarantee_on) if p>0.5]

s4 = figure(width=250, plot_height=250, title=animal)
ncorrect = np.array([float(n) for n in ncorrect])/np.array([float(t) for t in ntrials])
nfail = np.array([float(n) for n in nfail])/np.array([float(t) for t in ntrials])
nignore = np.array([float(n) for n in nignore])/np.array([float(t) for t in ntrials])

s4.line(range(nsessions), ncorrect, line_width=lwidth, line_color=c_success, line_alpha=0.5)
s4.line(range(nsessions), nfail, line_width=lwidth, line_color=c_fail, line_alpha=0.5)
s4.line(range(nsessions), nignore, line_width=lwidth, line_color=c_ignore, line_alpha=0.5)
s4.circle(flag_prereward, np.ones((len(flag_prereward),))*flagpos1, size=flagsize, color=flagcol1, alpha=0.5)
s4.triangle(flag_guarantee, np.ones((len(flag_guarantee),))*flagpos2, size=flagsize, color=flagcol2, alpha=0.5)


p = gridplot([[s1,s2], [s3,s4]])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6964d828-f9d9-4013-9a3a-5dc3c77ae0e5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6964d828-f9d9-4013-9a3a-5dc3c77ae0e5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6964d828-f9d9-4013-9a3a-5dc3c77ae0e5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6964d828-f9d9-4013-9a3a-5dc3c77ae0e5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2ba48846-1c90-497f-b730-d9754ae16216":{"roots":{"references":[{"attributes":{"data_source":{"id":"fc229ac9-dbb7-4efa-ad90-744d41fa2965","type":"ColumnDataSource"},"glyph":{"id":"7a53a27a-1b10-4bdc-9061-76c50a6bb8ea","type":"Triangle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0200cae4-8779-49e3-b46c-c56f23503137","type":"Triangle"},"selection_glyph":null},"id":"b4c1aa2b-5ef6-42d4-b84e-30c221c39b8c","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.5},"line_color":{"value":"navy"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"9d702715-b89c-4c00-a35d-f1884daf659f","type":"Line"},{"attributes":{"data_source":{"id":"483ab670-c60a-499e-94b3-e7c7ae407a6d","type":"ColumnDataSource"},"glyph":{"id":"260cf956-312d-44bd-a544-f462a5427ede","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"517a1700-d5fa-4823-b590-45568f5b968a","type":"Circle"},"selection_glyph":null},"id":"8c76f622-09cf-4455-87a0-0e9d4a4c7753","type":"GlyphRenderer"},{"attributes":{},"id":"1a895eb6-f853-4c5b-9100-cd6938d401aa","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"dcb504c8-2608-4593-a6de-165fb015812f","type":"ColumnDataSource"},"glyph":{"id":"13b14206-bd2b-4f22-9d0b-b4734dee90bf","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"90b1c7ef-bc15-45cf-930c-9f20e818ca73","type":"Circle"},"selection_glyph":null},"id":"8c311a0d-ec7f-4e25-8fc2-e9dc70a6ea8e","type":"GlyphRenderer"},{"attributes":{"children":[{"id":"f935d50c-d40a-45b3-888c-b8051c908efb","type":"Row"},{"id":"c49b6f01-4fe1-4efa-9ab7-21575d28c010","type":"Row"}]},"id":"0392c814-bd63-4816-93ea-599078b25812","type":"Column"},{"attributes":{"plot":{"id":"5516b105-41bd-40c7-bc8e-09ec92a0a199","subtype":"Figure","type":"Plot"}},"id":"efe83d1e-0d5c-4d6b-bdf5-69e2cf59a03a","type":"SaveTool"},{"attributes":{"data_source":{"id":"9bb207ce-2228-4555-ba52-c5f41c71d50b","type":"ColumnDataSource"},"glyph":{"id":"d2774143-98c1-414a-bef8-340ac22311de","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"05ef5f00-55a5-4254-b40f-a9134fb810dd","type":"Line"},"selection_glyph":null},"id":"a0e009a5-7398-42c7-a359-5eda389c3d14","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"80272eb7-bb92-40d6-9a30-bb87a794d920","type":"BoxAnnotation"},"plot":{"id":"4ae8aa9b-fd50-4b3c-a6ae-ac49ac4c9c5b","subtype":"Figure","type":"Plot"}},"id":"ae3431e5-cd31-4f81-8cb8-90411efc5e12","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"7fe4d8d3-0ce9-47aa-8d62-7533962318d0","type":"Triangle"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"8f7fd7ff-8f32-416c-b5e0-ec34ae2cb120","type":"Line"},{"attributes":{"plot":null,"text":"Athena"},"id":"6f3126be-36a5-40c1-a10e-ecdb7f7782df","type":"Title"},{"attributes":{"plot":{"id":"4ae8aa9b-fd50-4b3c-a6ae-ac49ac4c9c5b","subtype":"Figure","type":"Plot"}},"id":"94bc057c-776d-45e4-8b30-f185b6c829d5","type":"ResetTool"},{"attributes":{"line_alpha":{"value":0.5},"line_color":{"value":"firebrick"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"277fbf68-1162-4eda-ad48-1293459a2414","type":"Line"},{"attributes":{"callback":null},"id":"c588b7ed-4620-4a6c-9899-7a2b9264152d","type":"DataRange1d"},{"attributes":{},"id":"9b278cc8-892b-49ee-ae8e-48361f9d7210","type":"BasicTicker"},{"attributes":{},"id":"917cbdc7-e291-441a-974f-45240d8e9a7c","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[],"y":{"__ndarray__":"","dtype":"float64","shape":[0]}}},"id":"dcb504c8-2608-4593-a6de-165fb015812f","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"4ae8aa9b-fd50-4b3c-a6ae-ac49ac4c9c5b","subty ...

# %%
n_prereward_on = [sum(data[animal][s]['trials'][t]['prereward'] for t in range(len(data[animal][s]['trials']))) for s in sorted(data[animal].keys())]
n_guarantee_on = [sum(data[animal][s]['trials'][t]['guarantee'] for t in range(len(data[animal][s]['trials']))) for s in sorted(data[animal].keys())]
print n_prereward_on
print n_guarantee_on
# Out:
# [67, 0, 0, 24, 12, 0, 0]
# [516, 359, 0, 603, 394, 283, 0]

# %%
sum(data[animal][s]['trials'][t]['prereward'] for t in range(len(data[animal][s]['trials'])))
# Out:
# 67

# %%
# Check respomnse times:
response_times = []
# for idx,(im,res) in enumerate(zip(test_trials, result_evs)):
#     response_time = (res.time - im['time'])/1E6
#     response_times.append(response_time)
for idx,(im,res) in enumerate(zip(image_events[0:len(result_evs)], result_evs)):
    response_time = (res.time - im.time)/1E6
    response_times.append(response_time)
    
# Plot histogram of response-times:
p1 = figure(title="Response time from stim onset (s)",tools="save, zoom_in, zoom_out, pan",
            background_fill_color="white")

hist, edges = np.histogram(response_times, density=True, bins=20)
p1.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
        fill_color="#036564", line_color="#033649")
show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="45c326cb-7baf-4906-b2e0-bc589a46a6e5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("45c326cb-7baf-4906-b2e0-bc589a46a6e5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("45c326cb-7baf-4906-b2e0-bc589a46a6e5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '45c326cb-7baf-4906-b2e0-bc589a46a6e5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"efa93291-08aa-4d52-8dc8-6a93a8452b0c":{"roots":{"references":[{"attributes":{},"id":"abd82257-af0c-4d23-8489-f1c9035ecf7c","type":"LinearScale"},{"attributes":{"callback":null},"id":"d41a8851-0d3e-494a-81b2-a60605f007cb","type":"DataRange1d"},{"attributes":{"formatter":{"id":"cb583d6f-a959-48ad-869c-3b69f6b1bc05","type":"BasicTickFormatter"},"plot":{"id":"418c5c10-6ad4-47fc-b0bf-dd2c9bf5432c","subtype":"Figure","type":"Plot"},"ticker":{"id":"6f53a3f1-ac62-4d0a-90cf-4ef9683587f8","type":"BasicTicker"}},"id":"72315c7d-66c1-47e9-8275-0278461672ae","type":"LinearAxis"},{"attributes":{"formatter":{"id":"a23be90a-4f83-4367-aace-0fdb609cb250","type":"BasicTickFormatter"},"plot":{"id":"418c5c10-6ad4-47fc-b0bf-dd2c9bf5432c","subtype":"Figure","type":"Plot"},"ticker":{"id":"e26d89de-d56a-466a-8608-615d6232950a","type":"BasicTicker"}},"id":"c4e91897-450d-4ddd-a09c-5854b04c3d76","type":"LinearAxis"},{"attributes":{"callback":null},"id":"34cf7290-7bfa-4f69-b7ae-ab0a49b34a66","type":"DataRange1d"},{"attributes":{},"id":"5b0b3ca3-cea6-4ff7-87e8-933657d97215","type":"LinearScale"},{"attributes":{"plot":{"id":"418c5c10-6ad4-47fc-b0bf-dd2c9bf5432c","subtype":"Figure","type":"Plot"},"ticker":{"id":"e26d89de-d56a-466a-8608-615d6232950a","type":"BasicTicker"}},"id":"0606efd7-a645-4c98-bc16-371c580e6a85","type":"Grid"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"898847b0-0d91-4a75-b679-bda56b4c9a2b","type":"Quad"},{"attributes":{},"id":"e26d89de-d56a-466a-8608-615d6232950a","type":"BasicTicker"},{"attributes":{},"id":"6f53a3f1-ac62-4d0a-90cf-4ef9683587f8","type":"BasicTicker"},{"attributes":{"plot":{"id":"418c5c10-6ad4-47fc-b0bf-dd2c9bf5432c","subtype":"Figure","type":"Plot"}},"id":"80c31238-5112-416d-9d13-c5ba32d692ef","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"418c5c10-6ad4-47fc-b0bf-dd2c9bf5432c","subtype":"Figure","type":"Plot"},"ticker":{"id":"6f53a3f1-ac62-4d0a-90cf-4ef9683587f8","type":"BasicTicker"}},"id":"e273f1cc-5c27-4a61-a2d8-62008b296a78","type":"Grid"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8230fa90-77d1-4dce-846a-290759355ef3","type":"SaveTool"},{"id":"f8598a96-3f9d-4ee2-9e8b-b9195ad7581f","type":"ZoomInTool"},{"id":"58b53cdc-90dd-4123-a58e-92523967344f","type":"ZoomOutTool"},{"id":"80c31238-5112-416d-9d13-c5ba32d692ef","type":"PanTool"}]},"id":"249e0eb2-d488-404f-86f9-ec2f37419f9d","type":"Toolbar"},{"attributes":{"plot":{"id":"418c5c10-6ad4-47fc-b0bf-dd2c9bf5432c","subtype":"Figure","type":"Plot"}},"id":"8230fa90-77d1-4dce-846a-290759355ef3","type":"SaveTool"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#036564"},"left":{"field":"left"},"line_color":{"value":"#033649"},"right":{"field":"right"},"top":{"field":"top"}},"id":"c85be8a7-eb00-4b1b-8664-ab830f39c74b","type":"Quad"},{"attributes":{},"id":"4a58bfca-b9d1-44fd-9b16-344b7206ef20","type":"ToolEvents"},{"attributes":{"background_fill_color":{"value":"white"},"below":[{"id":"c4e91897-450d-4ddd-a09c-5854b04c3d76","type":"LinearAxis"}],"left":[{"id":"72315c7d-66c1-47e9-8275-0278461672ae","type":"LinearAxis"}],"renderers":[{"id":"c4e91897-450d-4ddd-a09c-5854b04c3d76","type":"LinearAxis"},{"id":"0606efd7-a645-4c98-bc16-371c580e6a85","type":"Grid"},{"id":"72315c7d-66c1-47e9-8275-0278461672ae","type":"LinearAxis"},{"id":"e273f1cc-5c27-4a61-a2d8-62008b296a78","type":"Grid"},{"id":"1da26b58-8cce-4031-a409-328edf314d7e","type":"GlyphRenderer"}],"title":{"id":"07dea810-edc6-40a3-8511-c6504e50278b","type":"Title"},"tool_events":{"id":"4a58bfca-b9d1-44fd-9b16-344b7206ef20","type":"ToolEvents"},"toolbar":{"id":"249e0eb2-d488-404f-86f9-ec2f37419f9d","type":"Toolbar"},"x_range":{"id":"d41a8851-0d3e-494a-81b2-a60605f007cb","type":"DataRange1d"},"x_scale":{"id":"5b0b3c ...

# %%
# Parse stimulus info for each trial:
print "Found %i image trials." % len(image_events)
print "Found %i stimulus update events across trials." % len(all_trial_events)

# GET TRIAL INFO FOR DB:
trial = dict((i+1, dict()) for i in range(len(image_events)))
image_events = sorted(image_events, key=get_timekey)
trial_events = sorted(all_trial_events, key=get_timekey)
runstart_time = trial_events[0].time
for trialidx,iev in enumerate(sorted(image_events, key=get_timekey)):
    trialnum = trialidx + 1
    blankidx = trialidx*2 + 1
    trial[trialnum]['start_time_ms'] = round(iev.time/1E3)
    #trial[trialnum]['end_time_ms'] = round((trial_events[blankidx].time + session_info['ITI'])/1E3)
    ori = iev.value[1]['rotation']
    sf = iev.value[1]['frequency'] #round(iev.value[1]['frequency'], 2)
    stimname = 'grating-ori-%i-sf-%0.2f' % (ori, sf)
    stimpos = [iev.value[1]['xoffset'], iev.value[1]['yoffset']]
    stimsize = iev.value[1]['height']
    trial[trialnum]['stimuli'] = {'stimulus': stimname, 'position': stimpos, 'scale': stimsize}
    trial[trialnum]['stim_on_times'] = round((iev.time - runstart_time)/1E3)
    trial[trialnum]['stim_off_times'] = round((trial_events[blankidx].time - runstart_time)/1E3)

print "Trial 1 info:"
print trial[2]
# Out:
# Found 507 image trials.
# Found 1014 stimulus update events across trials.
# Trial 1 info:
# {'stim_off_times': 28417.0, 'stimuli': {'stimulus': 'grating-ori-0-sf-0.06', 'position': [0, 0], 'scale': 100}, 'start_time_ms': 3220546.0, 'stim_on_times': 24367.0}

# %%
# Check stimulus ON times:
stim_on_durations = [trial[t]['stim_off_times'] - trial[t]['stim_on_times'] for t in trial.keys()]
print "longest: ", [v for v in stim_on_durations].index(max(stim_on_durations))

# Plot histogram of stimulus-ON durations
p1 = figure(title="Stimulus on durations (s)",tools="save, zoom_in, zoom_out, pan",
            background_fill_color="white")

hist, edges = np.histogram(np.array(stim_on_durations)/1E3, density=True, bins=20)
p1.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
        fill_color="#036564", line_color="#033649")
show(p1)
# Out:
# longest:  443
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9b2fa4f8-3a93-4963-b86a-958560fdf697"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9b2fa4f8-3a93-4963-b86a-958560fdf697");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9b2fa4f8-3a93-4963-b86a-958560fdf697");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9b2fa4f8-3a93-4963-b86a-958560fdf697' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b6013a1c-ad3b-4103-a0a3-aca1fd9d896c":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8310ab77-6c3f-4468-977e-0375b807e21c","type":"SaveTool"},{"id":"39f08a5d-4348-4c23-ac76-c96ff69a8b4b","type":"ZoomInTool"},{"id":"0621713a-3752-469d-a8f4-6af393969e78","type":"ZoomOutTool"},{"id":"060670ac-c404-4b43-9903-e48335ef49c9","type":"PanTool"}]},"id":"fc8cc6ee-0588-44ca-bdd9-8501836a496a","type":"Toolbar"},{"attributes":{},"id":"0bafb416-a6ec-4159-b647-caff8cc962cd","type":"LinearScale"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#036564"},"left":{"field":"left"},"line_color":{"value":"#033649"},"right":{"field":"right"},"top":{"field":"top"}},"id":"9f6e1108-b050-4fb1-a2a7-19afc601143b","type":"Quad"},{"attributes":{"callback":null},"id":"c80841a1-94f4-41c4-8787-703ecc6d2e32","type":"DataRange1d"},{"attributes":{"callback":null},"id":"3a7ee913-85f5-4a53-ad67-07344f8366cb","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"f183c267-3e98-4381-b20b-1da02d2aec4a","subtype":"Figure","type":"Plot"},"ticker":{"id":"d757aa70-64f3-471b-b891-4c8aeda5f163","type":"BasicTicker"}},"id":"fb6fa262-b814-4f12-bfeb-a1b0a90dca96","type":"Grid"},{"attributes":{"plot":null,"text":"Stimulus on durations (s)"},"id":"bea20968-d27c-48ee-8477-050c2b6fd8e9","type":"Title"},{"attributes":{},"id":"48d45f4a-c261-4371-8949-860f44801a31","type":"ToolEvents"},{"attributes":{},"id":"d757aa70-64f3-471b-b891-4c8aeda5f163","type":"BasicTicker"},{"attributes":{"background_fill_color":{"value":"white"},"below":[{"id":"6a875482-1987-47eb-a1c1-e74682009415","type":"LinearAxis"}],"left":[{"id":"8e60eda6-0fdc-4c26-9665-3c1e51fa92f3","type":"LinearAxis"}],"renderers":[{"id":"6a875482-1987-47eb-a1c1-e74682009415","type":"LinearAxis"},{"id":"96344b42-c9c2-455a-a4e7-7ae075e9d647","type":"Grid"},{"id":"8e60eda6-0fdc-4c26-9665-3c1e51fa92f3","type":"LinearAxis"},{"id":"fb6fa262-b814-4f12-bfeb-a1b0a90dca96","type":"Grid"},{"id":"1a85095a-10a7-450e-a851-0b704c47a9e3","type":"GlyphRenderer"}],"title":{"id":"bea20968-d27c-48ee-8477-050c2b6fd8e9","type":"Title"},"tool_events":{"id":"48d45f4a-c261-4371-8949-860f44801a31","type":"ToolEvents"},"toolbar":{"id":"fc8cc6ee-0588-44ca-bdd9-8501836a496a","type":"Toolbar"},"x_range":{"id":"c80841a1-94f4-41c4-8787-703ecc6d2e32","type":"DataRange1d"},"x_scale":{"id":"0bafb416-a6ec-4159-b647-caff8cc962cd","type":"LinearScale"},"y_range":{"id":"3a7ee913-85f5-4a53-ad67-07344f8366cb","type":"DataRange1d"},"y_scale":{"id":"d8733f35-d5fe-45e2-ac2f-3190ee3ffcc0","type":"LinearScale"}},"id":"f183c267-3e98-4381-b20b-1da02d2aec4a","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"f183c267-3e98-4381-b20b-1da02d2aec4a","subtype":"Figure","type":"Plot"}},"id":"060670ac-c404-4b43-9903-e48335ef49c9","type":"PanTool"},{"attributes":{},"id":"d87304a7-1111-4039-9fdc-222c9d83cabf","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"d87304a7-1111-4039-9fdc-222c9d83cabf","type":"BasicTickFormatter"},"plot":{"id":"f183c267-3e98-4381-b20b-1da02d2aec4a","subtype":"Figure","type":"Plot"},"ticker":{"id":"fd592c3f-c19f-4095-a757-e75233ba3311","type":"BasicTicker"}},"id":"6a875482-1987-47eb-a1c1-e74682009415","type":"LinearAxis"},{"attributes":{},"id":"d8733f35-d5fe-45e2-ac2f-3190ee3ffcc0","type":"LinearScale"},{"attributes":{},"id":"fd592c3f-c19f-4095-a757-e75233ba3311","type":"BasicTicker"},{"attributes":{"plot":{"id":"f183c267-3e98-4381-b20b-1da02d2aec4a","subtype":"Figure","type":"Plot"}},"id":"39f08a5d-4348-4c23-ac76-c96ff69a8b4b","type":"ZoomInTool"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"24c0d927-78ba-41c3-8400-8e6dd14e8df2","type":"Quad"},{"attributes":{"plot":{"id":"f183c267-3e98-4381-b20b-1da02d2aec4 ...

# %%
# Determine state of training flags:
pre_reward = df.get_events('flag_pre_reward')
pre_reward = [i for i in pre_reward if i.time>= t_boundary[0] and i.time<=t_boundary[1]]
print np.diff([i.time for i in pre_reward])/1E6

guarantee_reward = df.get_events('flag_guarantee_reward')
guarantee_reward = [i for i in guarantee_reward if i.time>=t_boundary[0] and i.time<=t_boundary[1]]
print np.diff([i.time for i in guarantee_reward])/1E6
print guarantee_reward
# Out:
# --------------------------------------------------
# NameError        Traceback (most recent call last)
# <ipython-input-25-dc24a6ef395f> in <module>()
#       1 # Determine state of training flags:
# ----> 2 pre_reward = df.get_events('flag_pre_reward')
#       3 pre_reward = [i for i in pre_reward if i.time>= t_boundary[0] and i.time<=t_boundary[1]]
#       4 print np.diff([i.time for i in pre_reward])/1E6
#       5
#
# NameError: name 'df' is not defined

# %%
# plot trials:
